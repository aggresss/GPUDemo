# %%
-
# Out:
# Using face detector (cascade) ../haarcascade_frontalface_default.xml
# ../italy_worldcup.jpg
# 11 faces detected
# ['./frontal-face-1.jpg', './frontal-face-2.jpg', './frontal-face-3.jpg', './frontal-face-4.jpg', './frontal-face-5.jpg', './frontal-face-6.jpg', './frontal-face-7.jpg', './frontal-face-8.jpg', './frontal-face-9.jpg', './frontal-face-10.jpg', './frontal-face-11.jpg']
# Executing on /gpu:0
# selected (fine-tuning) inception model
# ../22801/checkpoint-14999
# INFO:tensorflow:Restoring parameters from ../22801/checkpoint-14999
# Running multi-cropped image
# Guess @ 1 (8, 12), prob = 0.66
# Running multi-cropped image
# Guess @ 1 (25, 32), prob = 0.41
# Running multi-cropped image
# Guess @ 1 (25, 32), prob = 0.84
# Running multi-cropped image
# Guess @ 1 (8, 12), prob = 0.70
# Running multi-cropped image
# Guess @ 1 (8, 12), prob = 0.36
# Running multi-cropped image
# Guess @ 1 (25, 32), prob = 0.55
# Running multi-cropped image
# Guess @ 1 (25, 32), prob = 0.45
# ...
